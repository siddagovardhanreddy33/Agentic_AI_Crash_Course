# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI

load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model = 'gemini-2.5-flash')
llm
# Out:
# ChatGoogleGenerativeAI(output_version=None, profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-03-20', 'last_updated': '2025-06-05', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True}, google_api_key=SecretStr('**********'), location=None, model='gemini-2.5-flash', client=<google.genai.client.Client object at 0x000002216A3F9250>, default_metadata=(), model_kwargs={})

# %%
with open('blood_work.txt' , 'r') as f:
    blood_report = f.read()

print(blood_report[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
print(blood_report)
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%              (Normal: 41â€“53%)
# WBC:               6.8 x10^3/uL     (Normal: 4.5â€“11.0)
# Platelets:         220 x10^3/uL     (Normal: 150â€“400)
#
# LIPID PANEL
# -----------
# Total Cholesterol: 238 mg/dL        (Normal: <200)
# LDL Cholesterol:   162 mg/dL        (Normal: <100)
# HDL Cholesterol:   36 mg/dL         (Normal: >40)
# Triglycerides:     188 mg/dL        (Normal: <150)
#
# METABOLIC PANEL
# ---------------
# Glucose (Fasting): 92 mg/dL         (Normal: 70â€“99)
# HbA1c:             5.3%             (Normal: <5.7%)
# Creatinine:        1.0 mg/dL        (Normal: 0.7â€“1.3)
# eGFR:              82 mL/min        (Normal: >60)
#
# LIVER FUNCTION
# --------------
# ALT:               28 U/L           (Normal: 7â€“40)
# AST:               25 U/L           (Normal: 10â€“40)
# Bilirubin Total:   0.8 mg/dL        (Normal: 0.2â€“1.2)
#
# Reviewing Physician: Dr. Priya Nair

# %%
extraction_prompt = f""" 
you are a medical data extraction assistant

from the blood report below , extract ALL test values and classify each as HIGH, LOW, or Normal 
based on the reference ranges provided in the report .

format your response as :
- Test Name:Value | Status:HIGH/LOW/NORMAL | Reference:range

Blood Report : {blood_report}

"""


extraction_response = llm.invoke(extraction_prompt)
extracted_values = extraction_response.text

print(extracted_values)
# Out:
# - Hemoglobin:15.1 g/dL | Status:NORMAL | Reference:13.5–17.5
# - Hematocrit:44% | Status:NORMAL | Reference:41–53%
# - WBC:6.8 x10^3/uL | Status:NORMAL | Reference:4.5–11.0
# - Platelets:220 x10^3/uL | Status:NORMAL | Reference:150–400
# - Total Cholesterol:238 mg/dL | Status:HIGH | Reference:<200
# - LDL Cholesterol:162 mg/dL | Status:HIGH | Reference:<100
# - HDL Cholesterol:36 mg/dL | Status:LOW | Reference:>40
# - Triglycerides:188 mg/dL | Status:HIGH | Reference:<150
# - Glucose (Fasting):92 mg/dL | Status:NORMAL | Reference:70–99
# - HbA1c:5.3% | Status:NORMAL | Reference:<5.7%
# - Creatinine:1.0 mg/dL | Status:NORMAL | Reference:0.7–1.3
# - eGFR:82 mL/min | Status:NORMAL | Reference:>60
# - ALT:28 U/L | Status:NORMAL | Reference:7–40
# - AST:25 U/L | Status:NORMAL | Reference:10–40
# - Bilirubin Total:0.8 mg/dL | Status:NORMAL | Reference:0.2–1.2

# %%
dite_prompt = f"""   
You are a clinical nutritionist specializing in Indian dietary habits.

Based on the blood work analysis below , write:
1. A short health summary in 4-5 lines explaining the patient's condition in simple language
2. A short , practical Indian dite plan having only two sections (1) foods to avoide , (2)foods to eat more of . 
Do not include any other sections in the dite plan

Blood Work Analysis : {extracted_values}

"""

dite_response = llm.invoke(dite_prompt)

print(dite_response.text)
# Out:
# Here is your health summary and diet plan:
#
# ### 1. Health Summary
#
# Your blood tests show healthy blood counts, blood sugar, and organ functions. However, your cholesterol levels need attention. Your "bad" cholesterol (LDL) and triglycerides are elevated, while your "good" cholesterol (HDL) is low. This indicates a higher risk for heart health issues, which can be significantly improved through dietary adjustments and lifestyle changes.
#
# ### 2. Practical Indian Diet Plan
#
# **Foods to Avoid:**
#
# *   Deep-fried items like samosas, pakoras, puri, bhature, and commercially fried snacks.
# *   Processed foods, bakery items (biscuits, cakes, pastries), and excessive sweets (mithai).
# *   High-fat dairy products like full-fat milk, malai, khoya, and excessive ghee/butter.
# *   Red meat (mutton, beef) and organ meats.
# *   Sugary drinks, fruit juices with added sugar, and refined flour products (maida-based breads, naan).
#
# **Foods to Eat More Of:**
#
# *   **Whole Grains:** Oats (daliya), barley (jau), brown rice, millets (ragi, jowar, bajra), and whole wheat roti.
# *   **Lentils & Pulses:** All varieties of dals (moong, masoor, arhar, chana), rajma, chole, and sprouts.
# *   **Vegetables & Fruits:** A wide variety of fresh vegetables (especially leafy greens like palak, methi) and fruits (apples, guavas, berries, papaya).
# *   **Healthy Fats:** Moderate amounts of nuts (almonds, walnuts), seeds (flaxseeds, chia seeds), and cooking oils like rice bran, mustard, or olive oil.
# *   **Lean Protein:** Fish (especially fatty fish like salmon, mackerel), skinless chicken, tofu, and low-fat dairy products like skim milk and curd.
# *   **Herbs & Spices:** Incorporate garlic, ginger, turmeric, fenugreek, and other beneficial Indian spices into your cooking.
